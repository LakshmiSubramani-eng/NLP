# %% [markdown]
# # Data

# %%
text ='''Natural Language Processing (NLP) is a branch of artificial intelligence that deals with the interaction between computers and human languages. It involves the use of advanced algorithms and techniques to analyze, understand, and generate human language. NLP plays a vital role in various applications such as speech recognition, machine translation, sentiment analysis, and text summarization. With the increasing use of natural language in various industries such as healthcare, finance, and e-commerce, NLP has become an essential tool to automate processes and improve efficiency. The field of NLP is constantly evolving, with new techniques and technologies being developed to improve the accuracy and functionality of NLP systems. Overall, NLP is a crucial aspect of artificial intelligence and will continue to play a significant role in shaping the future of technology.'''

# %%
text
# Out:
# 'Natural Language Processing (NLP) is a branch of artificial intelligence that deals with the interaction between computers and human languages. It involves the use of advanced algorithms and techniques to analyze, understand, and generate human language. NLP plays a vital role in various applications such as speech recognition, machine translation, sentiment analysis, and text summarization. With the increasing use of natural language in various industries such as healthcare, finance, and e-commerce, NLP has become an essential tool to automate processes and improve efficiency. The field of NLP is constantly evolving, with new techniques and technologies being developed to improve the accuracy and functionality of NLP systems. Overall, NLP is a crucial aspect of artificial intelligence and will continue to play a significant role in shaping the future of technology.'

# %% [markdown]
# # Sentence tokenization

# %%
pip install nltk
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\laksh\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
from nltk.tokenize import sent_tokenize
sentences = sent_tokenize(text)

# %%
sentences
# Out:
# ['Natural Language Processing (NLP) is a branch of artificial intelligence that deals with the interaction between computers and human languages.',
#  'It involves the use of advanced algorithms and techniques to analyze, understand, and generate human language.',
#  'NLP plays a vital role in various applications such as speech recognition, machine translation, sentiment analysis, and text summarization.',
#  'With the increasing use of natural language in various industries such as healthcare, finance, and e-commerce, NLP has become an essential tool to automate processes and improve efficiency.',
#  'The field of NLP is constantly evolving, with new techniques and technologies being developed to improve the accuracy and functionality of NLP systems.',
#  'Overall, NLP is a crucial aspect of artificial intelligence and will continue to play a significant role in shaping the future of technology.']

# %% [markdown]
# # Word tokenization

# %%
from nltk.tokenize import word_tokenize
words = word_tokenize(text)

# %%
words
# Out:
# ['Natural',
#  'Language',
#  'Processing',
#  '(',
#  'NLP',
#  ')',
#  'is',
#  'a',
#  'branch',
#  'of',
#  'artificial',
#  'intelligence',
#  'that',
#  'deals',
#  'with',
#  'the',
#  'interaction',
#  'between',
#  'computers',
#  'and',
#  'human',
#  'languages',
#  '.',
#  'It',
#  'involves',
#  'the',
#  'use',
#  'of',
#  'advanced',
#  'algorithms',
#  'and',
#  'techniques',
#  'to',
#  'analyze',
#  ',',
#  'understand',
#  ',',
#  'and',
#  'generate',
#  'human',
#  'language',
#  '.',
#  'NLP',
#  'plays',
#  'a',
#  'vital',
#  'role',
#  'in',
#  'various',
#  'applications',
#  'such',
#  'as',
#  'speech',
#  'recognition',
#  ',',
#  'machine',
#  'translation',
#  ',',
#  'sentiment',
#  'analysis',
#  ',',
#  'and',
#  'text',
#  'summarization',
#  '.',
#  'With',
#  'the',
#  'increasing',
#  'use',
#  'of',
#  'natural',
#  'language',
#  'in',
#  'various',
#  'industries',
#  'such',
#  'as',
#  'healthcare',
#  ',',
#  'finance',
#  ',',
#  'and',
# ...

# %% [markdown]
# # lower_sentences

# %%
lower_sentences = [sentence.lower() for sentence in sentences]

# %%
lower_sentences
# Out:
# ['natural language processing (nlp) is a branch of artificial intelligence that deals with the interaction between computers and human languages.',
#  'it involves the use of advanced algorithms and techniques to analyze, understand, and generate human language.',
#  'nlp plays a vital role in various applications such as speech recognition, machine translation, sentiment analysis, and text summarization.',
#  'with the increasing use of natural language in various industries such as healthcare, finance, and e-commerce, nlp has become an essential tool to automate processes and improve efficiency.',
#  'the field of nlp is constantly evolving, with new techniques and technologies being developed to improve the accuracy and functionality of nlp systems.',
#  'overall, nlp is a crucial aspect of artificial intelligence and will continue to play a significant role in shaping the future of technology.']

# %% [markdown]
# # lower_words

# %%
lower_words = [word.lower() for word in words]

# %%
len(lower_words)
# Out:
# 147

# %% [markdown]
# # Stopwords

# %%
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

# %%
import nltk
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\laksh\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\laksh\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\laksh\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\laksh\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %% [markdown]
# 1 Stopwords is a list of commonly used words in the English language that are typically removed from text data before further processing.
#
# 2 Punkt is a module for tokenizing text and is used to divide text into a list of words.
#
# 3 Wordnet is a lexical database for the English language that is used for natural language processing tasks such as text classification, text similarity, and text generation.
#
# 4 Qmw-1.4 is the Open Multilingual WordNet (OMW) which is a lexical database for many languages.

# %%
stop_words = set(stopwords.words("english"))
stop_words
# Out:
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  "he's",
#  'her',
#  'here',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  "i'd",
#  "i'll",
#  "i'm",
#  "i've",
#  'if',
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it'd",
#  "it'll",
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'll',
#  'm',
#  'ma',
# ...

# %%
filtered_words = [word for word in words if word.lower() not in stop_words and word.isalpha()]

# %%
len(filtered_words)
# Out:
# 78

# %% [markdown]
# # Stemming

# %%
from nltk.stem import PorterStemmer, WordNetLemmatizer
from nltk.tokenize import word_tokenize

# %%
# Stemming
stemmer = PorterStemmer()
stemmed_words = [stemmer.stem(word) for word in filtered_words]
stemmed_words
# Out:
# ['natur',
#  'languag',
#  'process',
#  'nlp',
#  'branch',
#  'artifici',
#  'intellig',
#  'deal',
#  'interact',
#  'comput',
#  'human',
#  'languag',
#  'involv',
#  'use',
#  'advanc',
#  'algorithm',
#  'techniqu',
#  'analyz',
#  'understand',
#  'gener',
#  'human',
#  'languag',
#  'nlp',
#  'play',
#  'vital',
#  'role',
#  'variou',
#  'applic',
#  'speech',
#  'recognit',
#  'machin',
#  'translat',
#  'sentiment',
#  'analysi',
#  'text',
#  'summar',
#  'increas',
#  'use',
#  'natur',
#  'languag',
#  'variou',
#  'industri',
#  'healthcar',
#  'financ',
#  'nlp',
#  'becom',
#  'essenti',
#  'tool',
#  'autom',
#  'process',
#  'improv',
#  'effici',
#  'field',
#  'nlp',
#  'constantli',
#  'evolv',
#  'new',
#  'techniqu',
#  'technolog',
#  'develop',
#  'improv',
#  'accuraci',
#  'function',
#  'nlp',
#  'system',
#  'overal',
#  'nlp',
#  'crucial',
#  'aspect',
#  'artifici',
#  'intellig',
#  'continu',
#  'play',
#  'signific',
#  'role',
#  'shape',
# ...

# %% [markdown]
# # Lemmatization

# %%
lemmatizer = WordNetLemmatizer()
lemmatized_words = [lemmatizer.lemmatize(word) for word in filtered_words]
lemmatized_words
# Out:
# ['Natural',
#  'Language',
#  'Processing',
#  'NLP',
#  'branch',
#  'artificial',
#  'intelligence',
#  'deal',
#  'interaction',
#  'computer',
#  'human',
#  'language',
#  'involves',
#  'use',
#  'advanced',
#  'algorithm',
#  'technique',
#  'analyze',
#  'understand',
#  'generate',
#  'human',
#  'language',
#  'NLP',
#  'play',
#  'vital',
#  'role',
#  'various',
#  'application',
#  'speech',
#  'recognition',
#  'machine',
#  'translation',
#  'sentiment',
#  'analysis',
#  'text',
#  'summarization',
#  'increasing',
#  'use',
#  'natural',
#  'language',
#  'various',
#  'industry',
#  'healthcare',
#  'finance',
#  'NLP',
#  'become',
#  'essential',
#  'tool',
#  'automate',
#  'process',
#  'improve',
#  'efficiency',
#  'field',
#  'NLP',
#  'constantly',
#  'evolving',
#  'new',
#  'technique',
#  'technology',
#  'developed',
#  'improve',
#  'accuracy',
#  'functionality',
#  'NLP',
#  'system',
#  'Overall',
#  'NLP',
#  'crucial',
#  'aspect',
# ...

# %% [markdown]
# # Unigram,Bigrams .. Ngrams

# %%
from nltk import ngrams

# Unigrams
unigrams = ngrams(filtered_words, 1)
print("Unigrams:", unigrams)
# Bigrams
bigrams = ngrams(filtered_words, 2)
print("Bigrams:", bigrams)

# Trigrams
trigrams = ngrams(filtered_words, 4)
print("Trigrams:", trigrams)
# Out:
# Unigrams: <generator object ngrams at 0x0000019B08DC6340>
# Bigrams: <generator object ngrams at 0x0000019B08DC6140>
# Trigrams: <generator object ngrams at 0x0000019B08DC6540>

# %% [markdown]
# The ngrams function from the nltk library returns an iterable object, such as a zip object, that contains the n-grams.

# %%
# unigrams
unigrams = list(ngrams(filtered_words, 1))

# bigrams
bigrams = list(ngrams(filtered_words, 2))

# Trigrams
trigrams = list(ngrams(filtered_words, 4))

# %%
trigrams
# Out:
# [('Natural', 'Language', 'Processing', 'NLP'),
#  ('Language', 'Processing', 'NLP', 'branch'),
#  ('Processing', 'NLP', 'branch', 'artificial'),
#  ('NLP', 'branch', 'artificial', 'intelligence'),
#  ('branch', 'artificial', 'intelligence', 'deals'),
#  ('artificial', 'intelligence', 'deals', 'interaction'),
#  ('intelligence', 'deals', 'interaction', 'computers'),
#  ('deals', 'interaction', 'computers', 'human'),
#  ('interaction', 'computers', 'human', 'languages'),
#  ('computers', 'human', 'languages', 'involves'),
#  ('human', 'languages', 'involves', 'use'),
#  ('languages', 'involves', 'use', 'advanced'),
#  ('involves', 'use', 'advanced', 'algorithms'),
#  ('use', 'advanced', 'algorithms', 'techniques'),
#  ('advanced', 'algorithms', 'techniques', 'analyze'),
#  ('algorithms', 'techniques', 'analyze', 'understand'),
#  ('techniques', 'analyze', 'understand', 'generate'),
#  ('analyze', 'understand', 'generate', 'human'),
#  ('understand', 'generate', 'human', 'language'),
# ...

# %%
unigrams
# Out:
# [('Natural',),
#  ('Language',),
#  ('Processing',),
#  ('NLP',),
#  ('branch',),
#  ('artificial',),
#  ('intelligence',),
#  ('deals',),
#  ('interaction',),
#  ('computers',),
#  ('human',),
#  ('languages',),
#  ('involves',),
#  ('use',),
#  ('advanced',),
#  ('algorithms',),
#  ('techniques',),
#  ('analyze',),
#  ('understand',),
#  ('generate',),
#  ('human',),
#  ('language',),
#  ('NLP',),
#  ('plays',),
#  ('vital',),
#  ('role',),
#  ('various',),
#  ('applications',),
#  ('speech',),
#  ('recognition',),
#  ('machine',),
#  ('translation',),
#  ('sentiment',),
#  ('analysis',),
#  ('text',),
#  ('summarization',),
#  ('increasing',),
#  ('use',),
#  ('natural',),
#  ('language',),
#  ('various',),
#  ('industries',),
#  ('healthcare',),
#  ('finance',),
#  ('NLP',),
#  ('become',),
#  ('essential',),
#  ('tool',),
#  ('automate',),
#  ('processes',),
#  ('improve',),
#  ('efficiency',),
#  ('field',),
#  ('NLP',),
#  ('constantly',),
#  ('evolving',),
#  ('new',),
# ...

# %%
bigrams
# Out:
# [('Natural', 'Language'),
#  ('Language', 'Processing'),
#  ('Processing', 'NLP'),
#  ('NLP', 'branch'),
#  ('branch', 'artificial'),
#  ('artificial', 'intelligence'),
#  ('intelligence', 'deals'),
#  ('deals', 'interaction'),
#  ('interaction', 'computers'),
#  ('computers', 'human'),
#  ('human', 'languages'),
#  ('languages', 'involves'),
#  ('involves', 'use'),
#  ('use', 'advanced'),
#  ('advanced', 'algorithms'),
#  ('algorithms', 'techniques'),
#  ('techniques', 'analyze'),
#  ('analyze', 'understand'),
#  ('understand', 'generate'),
#  ('generate', 'human'),
#  ('human', 'language'),
#  ('language', 'NLP'),
#  ('NLP', 'plays'),
#  ('plays', 'vital'),
#  ('vital', 'role'),
#  ('role', 'various'),
#  ('various', 'applications'),
#  ('applications', 'speech'),
#  ('speech', 'recognition'),
#  ('recognition', 'machine'),
#  ('machine', 'translation'),
#  ('translation', 'sentiment'),
#  ('sentiment', 'analysis'),
#  ('analysis', 'text'),
#  ('text', 'summarization'),
# ...

# %%
trigrams
# Out:
# [('Natural', 'Language', 'Processing'),
#  ('Language', 'Processing', 'NLP'),
#  ('Processing', 'NLP', 'branch'),
#  ('NLP', 'branch', 'artificial'),
#  ('branch', 'artificial', 'intelligence'),
#  ('artificial', 'intelligence', 'deals'),
#  ('intelligence', 'deals', 'interaction'),
#  ('deals', 'interaction', 'computers'),
#  ('interaction', 'computers', 'human'),
#  ('computers', 'human', 'languages'),
#  ('human', 'languages', 'involves'),
#  ('languages', 'involves', 'use'),
#  ('involves', 'use', 'advanced'),
#  ('use', 'advanced', 'algorithms'),
#  ('advanced', 'algorithms', 'techniques'),
#  ('algorithms', 'techniques', 'analyze'),
#  ('techniques', 'analyze', 'understand'),
#  ('analyze', 'understand', 'generate'),
#  ('understand', 'generate', 'human'),
#  ('generate', 'human', 'language'),
#  ('human', 'language', 'NLP'),
#  ('language', 'NLP', 'plays'),
#  ('NLP', 'plays', 'vital'),
#  ('plays', 'vital', 'role'),
#  ('vital', 'role', 'various'),
# ...
